# %% [markdown]
# ## SKlearn practice

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
import pandas as pd

# Data dictionary
data = {
    "area": [800, 1000, 1200, 1500, 1800, 2000, 2200, 2500, 2800, 3000],  # in square feet
    "price": [40, 55, 68, 85, 100, 112, 125, 140, 160, 175]  # in lakhs (₹)
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Save to CSV
df.to_csv("homeprice.csv", index=False)

print("CSV file 'homeprice.csv' created successfully.")
df
# Out:
# CSV file 'homeprice.csv' created successfully.
#    area  price
# 0   800     40
# 1  1000     55
# 2  1200     68
# 3  1500     85
# 4  1800    100
# 5  2000    112
# 6  2200    125
# 7  2500    140
# 8  2800    160
# 9  3000    175

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load data
df = pd.read_csv("homeprice.csv")

# Train model
reg = LinearRegression()
reg.fit(df[["area"]], df["price"])

# Plot scatter
plt.scatter(df["area"], df["price"], color='blue', marker='o')
plt.xlabel("Area (sq. ft.)")
plt.ylabel("Price (in ₹ Lakh)")
plt.title("Area vs Price of Homes")

# Plot regression line
plt.plot(df["area"], reg.predict(df[["area"]]), color='red', label="Regression Line")

# Add legend and show plot
plt.legend()
plt.grid(True)
plt.show()

# %%
reg= linear_model.LinearRegression()
reg.fit(df[["area"]],df["price"])
# Out:
# LinearRegression()

# %%
reg.predict([[2200]])
# Out:
# c:\Users\svish\OneDrive\Desktop\jupyter-notebook\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([124.94802172])

# %%
print("Slope (m):", reg.coef_[0])
print("Intercept (c):", reg.intercept_)
# Out:
# Slope (m): 0.05921256788207912
# Intercept (c): -5.319627618308743

# %%
0.05921256788207912*2200+-5.319627618308743
# Out:
# 124.94802172226531

# %%
d={"area":[100,200,300,400,500,600,700,800,900]}

d2=pd.DataFrame(d)
d2
d2.to_csv("areas.csv")
p=reg.predict(d2)
d["prices"]=p
 
d3=pd.DataFrame(d)
d3.to_csv("prediction.csv")
